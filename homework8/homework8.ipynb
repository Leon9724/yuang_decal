# %%
import numpy as np
import matplotlib.pyplot as plt

def make_sine_wave(x, A, w):
    return A * np.sin(w * x)

# %%
x = np.linspace(0, 2 * np.pi, 1000)
amplitudes = [0.5, 1, 1.5, 2]
frequencies = [1, 2, 3, 4]

plt.figure(figsize=(10, 5))
for A in amplitudes:
    for w in frequencies:
        y = make_sine_wave(x, A, w)
        plt.plot(x, y, label=f"A={A}, w={w}")

plt.ylabel("y = A·sin(w·x)")
plt.show()

# %%
# 2. 
x = np.linspace(0, 2 * np.pi, 1000)
plt.plot(x)
plt.show()

# %%
# 3. 
amplitudes = np.array([0.5, 1, 1.5, 2, 2.5])
frequencies = np.array([1, 2, 3, 4, 5])

plt.figure(figsize=(12, 6))

plt.plot(amplitudes, marker='o')
plt.title("Amplitude Values")
plt.ylabel("Amplitude")
plt.grid(True)

# %%
# 4.
fig = plt.figure(figsize=(10, 6))
x = np.linspace(0, 10, 114)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %%
# 5.
def make_sine_wave(x, A, w):
    return A * np.sin(w * x)

x = np.linspace(0, 2 * np.pi, 1000)

amplitudes = np.array([0.5, 1, 1.5, 2, 2.5])
frequencies = np.array([1, 2, 3, 4, 5])

plt.figure(figsize=(12, 6))

for A, w in zip(amplitudes, frequencies):
    y = make_sine_wave(x, A, w)
    plt.plot(x, y, label=f"A={A}, w={w}")

plt.title("amplitude and frequency arrays ")
plt.xlabel("x")
plt.ylabel("y = A·sin(w·x)")
plt.grid(True)

# Step 7: Show the plot
plt.show()

# %%
# 2.1
import pandas as pd

df = pd.read_csv('stars.csv')

print("First 5 rows of the dataset:")
print(df.head())

print("Number of rows and columns:")
print(df.shape)

print("Column names and data types:")
print(df.dtypes)
# Out:
# First 5 rows of the dataset:
#                Name  Distance (ly)  Mass (M☉)  Radius (R☉)  Temperature (K)  \
# 0  Proxima Centauri           4.24       0.12         0.14             3042
# 1  Alpha Centauri A           4.37       1.10         1.22             5790
# 2  Alpha Centauri B           4.37       0.91         0.86             5260
# 3    Barnard's Star           5.96       0.16         0.20             3134
# 4          Wolf 359           7.86       0.09         0.16             2800
#
#   Spectral_Type
# 0        M5.5Ve
# 1           G2V
# 2           K1V
# 3          M4Ve
# 4        M6.5Ve
# Number of rows and columns:
# (10, 6)
# Column names and data types:
# Name                object
# Distance (ly)      float64
# Mass (M☉)          float64
# Radius (R☉)        float64
# Temperature (K)      int64
# Spectral_Type       object
# dtype: object
# ---------------------------------------------------------------------------
# ...

# %%
# 2.2
# avg_mass = df["mass"].mean() KeyError: 'mass' Tells me the names is wrong whatever I try, I can't solve this
avg_temp = df["Temperature (K)"].mean()

# print(f"Average Mass: {avg_mass}")
print(f"Average Temperature: {avg_temp}")

print("-------------------------------------------------------------------------------------")

# largest_radius_star = df.loc[df['Radius (Râ˜‰)'].idxmax()]             same happened, frustrated.

# print("\nStar with the largest radius:")
# print(largest_radius_star)


print("-------------------------------------------------------------------------------------")

# m_type_count = df[df['spectral_type'].str.startswith('M')].shape[0]    again

# print(f"\nNumber of M-type stars: {m_type_count}")
# Out:
# Average Temperature: 6370.6
# -------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------

# %%
# 2.4 4. Sort the stars by distance and show the 3 closest ones

df = pd.read_csv('stars.csv')

closest_stars = df.sort_values(by='Distance (ly)').head(3) #keeps throwing KeyError: 'Distance(ly)' eventho this is writtten correctly

print(closest_stars)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2288\3992144917.py in ?()
#       1 # 2.4 4. Sort the stars by distance and show the 3 closest ones
#       2
#       3 df = pd.read_csv('stars.csv')
#       4
# ----> 5 closest_stars = df.sort_values(by='Distance(ly)').head(3)
#       6
#       7 print(closest_stars)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# ...

# %%
import pandas as pd
df = pd.read_csv('stars.csv')

m_type_stars = df[df['spectral_type'].str.startswith('M')] 
# KeyError: 'spectral_type' man what can I say

m_type_stars.to_csv('m_type_stars.csv', index=False)

print("Filtered M-type stars saved to m_type_stars.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'spectral_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 4
#       1 import pandas as pd
# ...

# %%
# 3.1
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset("penguins")

plt.figure(figsize=(15, 8)) 

plt.subplot(1, 2, 1)  
sns.histplot(penguins['flipper_length_mm'].dropna(), kde=True)

plt.subplot(1, 2, 2)  
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')

plt.show()

# %%
# 3.3, 3.4
import seaborn as sns
import matplotlib.pyplot as plt

penguins = sns.load_dataset("penguins")

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')
plt.title("Bill Length vs. Bill Depth")
plt.xlabel("Bill Length (mm)")
plt.ylabel("Bill Depth (mm)")
plt.legend(title="Species")

plt.subplot(1, 2, 2)
sns.histplot(penguins['body_mass_g'].dropna(), bins=20, kde=True)
plt.title("Body Mass Distribution")
plt.xlabel("Body Mass (g)")
plt.ylabel("Count")

plt.show()
